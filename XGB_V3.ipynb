# %% [markdown]
# ## <center>Global Biomass Estimation Using S2 and GEDI</center>
# ### <center>Extreme Gradient Boosting (XGB)</center>
# **<center>This ipynb notebook was created by Oliver Hegi</center>**
#
# This notebook contains the code for a Extreme Gradient Boosting (XGB). The predictors are Sentinel-2 images and the target is a set of GEDI biomass estimations.

# %% [markdown]
# #### Step 1 – Load the required packages

# %%
# %%capture --no-display
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %% [markdown]
# #### Step 2 – Load the input and target data.
# The data can be found in the folder /DATA

# %%
directory = 'DATA/'
Y = np.array(pd.read_csv(f'{directory}l_GEDI.csv', index_col=0)['0']) # of shape (10000,)
X = np.load(f'{directory}l_S2.npy', allow_pickle=True) # of shape (10000, 111, 111, 3) where each image is 111 pixels tall and 111 pixels wide and has three layers for RGB

# %% [markdown]
# #### STEP 3 – Standardize the data and flatten the images

# %%
mean, std = X.mean(), X.std()
X = (X - mean)/std # Only the input data needs to be standardized
X = X.reshape(X.shape[0], -1) # Shape is now 10000, 36963

# %% [markdown]
# #### STEP 4 – Train/test split

# %%
np.random.seed(1)
x_iis, x_test, y_iis, y_test = train_test_split(X, Y, test_size=0.2) #in-sample vs test
x_trn, x_val, y_trn, y_val = train_test_split(x_iis, y_iis, test_size=0.2) #train vs validate is drawn from the in-sample data

# %% [markdown]
# #### STEP 5 – Set up XGB model

# %%
model = xgb.XGBRegressor(objective ='reg:squarederror', colsample_bytree = 0.3, learning_rate = 0.1,
                max_depth = 10, alpha = 10, n_estimators = 40)

# %% [markdown]
# #### STEP 6 – Run model

# %%
model.fit(x_trn,y_trn, verbose=1, early_stopping_rounds=5, eval_set=[(x_trn,y_trn), (x_val, y_val)], eval_metric='logloss', sample_weight=(y_trn/10))
# Out:
# [0]	validation_0-logloss:-1318.26025	validation_1-logloss:-1305.71643
# [1]	validation_0-logloss:-1324.44080	validation_1-logloss:-1330.14246
# [2]	validation_0-logloss:-1324.67188	validation_1-logloss:-1338.57874
# [3]	validation_0-logloss:-1324.84973	validation_1-logloss:-1338.57922
# [4]	validation_0-logloss:-1324.85217	validation_1-logloss:-1338.57922
# [5]	validation_0-logloss:-1324.98682	validation_1-logloss:-1338.57922
# [6]	validation_0-logloss:-1325.01160	validation_1-logloss:-1338.57959
# [7]	validation_0-logloss:-1324.98120	validation_1-logloss:-1338.57959
# [8]	validation_0-logloss:-1325.05041	validation_1-logloss:-1338.57910
# [9]	validation_0-logloss:-1325.02295	validation_1-logloss:-1338.58862
# [10]	validation_0-logloss:-1325.05566	validation_1-logloss:-1338.58862
# [11]	validation_0-logloss:-1325.04834	validation_1-logloss:-1338.58862
# [12]	validation_0-logloss:-1325.05652	validation_1-logloss:-1338.58862
# [13]	validation_0-logloss:-1325.05908	validation_1-logloss:-1338.58862
# [14]	validation_0-logloss:-1324.99939	validation_1-logloss:-1338.58997
# [15]	validation_0-logloss:-1325.02185	validation_1-logloss:-1338.61231
# [16]	validation_0-logloss:-1325.02185	validation_1-logloss:-1338.61231
# [17]	validation_0-logloss:-1325.01599	validation_1-logloss:-1338.61231
# [18]	validation_0-logloss:-1325.02747	validation_1-logloss:-1338.62000
# [19]	validation_0-logloss:-1325.03467	validation_1-logloss:-1338.62000
# [20]	validation_0-logloss:-1325.01624	validation_1-logloss:-1338.62000
# [21]	validation_0-logloss:-1325.01624	validation_1-logloss:-1338.62000
# [22]	validation_0-logloss:-1325.01624	validation_1-logloss:-1338.62000
# XGBRegressor(alpha=10, base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.3, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.1, max_delta_step=0,
#              max_depth=10, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=40, n_jobs=8,
#              num_parallel_tree=1, predictor='auto', random_state=0,
#              reg_alpha=10, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %% [markdown]
# #### STEP 7 – Plot history

# %%
results = model.evals_result()
plt.plot(results['validation_0']['logloss'])
plt.plot(results['validation_1']['logloss'])
plt.title('Training and validation loss')
plt.ylabel('Logloss (negative)')
plt.xlabel('Epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# #### STEP 8 – Out-of-sample test accuracy
# Test the accuracy of the model on completelty untouched data

# %%
y_hat = model.predict(x_test) #x_test is untouched data
mean_squared_error(y_test, y_hat)
# Out:
# 2675.143970386427

# %% [markdown]
# #### STEP 9 – Plot predictions against actual values

# %%
ax = sns.histplot(x=y_test, y=y_hat, bins=400, cbar=True, cbar_kws=dict(shrink=0.75))
ax.set_ylabel('Predictions based on S2')
ax.set_xlabel('True GEDI values')
ax.axline([0, 0], [1, 1], linewidth=2)
lim = 60
ax.set_xlim(0,lim)
ax.set_ylim(0,lim)
ax.set_title('Confusion plot for the out-of-sample test data')
ax.plot()
# Out:
# []
